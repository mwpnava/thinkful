# %% [markdown]
# ### Challenge: Data cleaning & validation
#
# - Determine the five most common journals and the total articles for each.
# - Calculate the mean, median, and standard deviation of the open-access cost per article for each journal.
#
# - Real bonus round, identify the open access prices paid by subject area.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re #regex library
from fuzzywuzzy import fuzz

# %matplotlib inline

#CREATING AND PREPARING DATAFRAMES
    
#Creating original dataframe 
apc_original = pd.read_csv('WELLCOME_APC_original.csv', encoding ='ISO-8859-1')

#Creating a dataframe to clean 
apc = pd.read_csv('WELLCOME_APC.csv', encoding = 'ISO-8859-1')

#Removing white spaces from column names
for col in apc.columns:
    apc.rename(columns={col:col.replace(' ','_')},inplace=True)

apc.rename(columns={'COST_(£)_charged_to_Wellcome_(inc_VAT_when_charged)':'cost'},inplace=True)    
apc.head(5)
# Out:
#               PMID/PMCID Publisher           Journal_title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article_title      cost
# 0  Reduced parahippocampal cortical thickness in ...     £0.00
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64
# 4  Regioselective opening of myo-inositol orthoes...   £685.88

# %%
#Removing white spaces from the begging and final positions of the records

apc[['Journal_title','Publisher','Article_title']].apply(lambda x : str(x).strip().lstrip())
# Out:
# Journal_title    0                                  Psychologic...
# Publisher        0                                             ...
# Article_title    0       Reduced parahippocampal cortical thick...
# dtype: object

# %%
#Looking for NULL values
apc.isnull().sum()
apc['Journal_title'].nunique()
# Out:
# 984

# %%
#Functions


def getAbbreviation(string):
    
    """ Function: getAbbreviation 
        Parameters: a string with 1 or more words
        Return: a string's abbreviation, taking the first letter of each word in the string given
    """ 
    
    abbrev = []
    words = []
    pattern = re.compile('^[A-Z]{3}$')
    
    exclude_words = ['the','of','for','with','at','&','and','in','on','an']
    
    for w in str(string).split(' '):
       
        if w.lower() not in exclude_words:
            words.append(w)

    for word in words:
        if len(word) != 0 :
            result = pattern.match(word)
            if pattern.match(word):
                abbrev.append(word)
                break
            else:
                for letter in word[0]:
                    abbrev.append(letter[0])

    return ''.join(abbrev)



def getIntersectionP(x,y):
    
    """ Function: getIntersection 
    Parameters: x =       , y = 
    Return: a string's abbreviation, taking the first letter of each word in the string given
    """   
    
    if (x,y) in similarRowsPublisher.keys(): 
        return similarRowsPublisher[(x,y)]
    else:
        return -1
    
def getIntersectionJ(x,y):
    
    """ Function: getIntersection 
    Parameters: x =       , y = 
    Return: a string's abbreviation, taking the first letter of each word in the string given
    """   
    
    if (x,y) in similarRowsJournal.keys(): 
        return similarRowsJournal[(x,y)]
    else:
        return -1

    
def changeifSimilar(dataframe,c1,c2,c3):
    
    """ Function: changeifSimilar 
        Parameters: dataframe
                    c1 is the column's name where the original name is, this string may or may not change; 
                    c2 is the column's name where the proposed new name is. The suggestion is based on the number of matchs in dataset
                    c3 is the column's name where the original name abbreavtion is.
        Return: a string (it may be the original name or the one that matchs with similar names)
    """
      
    original_name = dataframe[c1]
    pattern = dataframe[c2]
    abb = dataframe[c3]

    ratio_name = fuzz.partial_ratio(str(pattern).lower(),str(original_name).lower())
    name = original_name
        
    if ((ratio_name > 89) or (original_name.upper() == abb)):        
        name = pattern
        
    else:
        for word in original_name.split():
            if word.upper() in abb :               
                name = pattern 
                break
    
    return name
    

    
def findMatch(dataframe,c1,c2,c3):

    """Function: findMatch
            Parameters: dataframe 
            c1 is the column's name where the abbreviation is.
            c2 is the column's name where the number of similar rows is.
            c3 is the column's name where the Publisher o Journal Title is.
            Return: a string (it's a suggested name based on how much matchs with similar names)

    """
    
    match = ''    
    abb = dataframe[c1] 
    maxRows = apc[apc[c1]==abb][c2].max()
    match = apc[(apc[c1]==abb)&(apc[c2]==maxRows)][c3].iloc[0]
    return match

# %%
apc['Publisher'] = apc_original['Publisher']


#STEP  : Creating abbreviation column (SET A= Abbreviations)
apc['Publisher_abbreviation'] = apc['Publisher'].apply(lambda x: getAbbreviation(x)) 
apc['Journal_abbreviation'] = apc['Journal_title'].apply(lambda x: getAbbreviation(x))


#STEP  : Lowerizing and titlerizing publishers' names (SET B = Names)
apc['Publisher'] = apc['Publisher'].apply(lambda x:str(x).lower().title())
apc['Journal_title'] = apc['Journal_title'].apply(lambda x:str(x).lower().title())



# STEP : Creating a new set (SET C = A ∩ B ) to verify if the intersection are same publishers or journal base on abbreviations
# or similiraty of names

intersectionPublisher = apc[['Publisher','Publisher_abbreviation']].groupby(['Publisher','Publisher_abbreviation'])['Publisher','Publisher_abbreviation'].count()

similarRowsPublisher={}
for ind,x in intersectionPublisher.iterrows():
    val = intersectionPublisher.loc[ind,'Publisher']
    similarRowsPublisher[ind] = val


intersectionJournal = apc[['Journal_title','Journal_abbreviation']].groupby(['Journal_title','Journal_abbreviation'])['Journal_title','Journal_abbreviation'].count()

similarRowsJournal={}
for ind,x in intersectionJournal.iterrows():
    val = intersectionJournal.loc[ind,'Journal_title']
    similarRowsJournal[ind] = val

    
    
apc['Publisher_similarRows'] = apc.apply(lambda x: getIntersectionP(x['Publisher'] ,x['Publisher_abbreviation']), axis=1)
apc['Journal_similarRows'] = apc.apply(lambda x: getIntersectionJ(x['Journal_title'] ,x['Journal_abbreviation']), axis=1)

#Finding matchs for Journal and Pubisher's names

apc['Publisher_match']=apc.apply(lambda x: findMatch(x,'Publisher_abbreviation','Publisher_similarRows','Publisher'),1)
apc['Journal_match']=apc.apply(lambda x: findMatch(x,'Journal_abbreviation','Journal_similarRows','Journal_title'),1)    

#Uniforming names if Journal and Pubisher's names are similar to others
apc['Publisher_newname'] = apc.apply(lambda x: changeifSimilar(x,'Publisher','Publisher_match','Publisher_abbreviation'),1)
apc['Journal_newname']=apc.apply(lambda x: changeifSimilar(x,'Journal_title','Journal_match','Journal_abbreviation'),1)

# %%
apc[['Publisher','Publisher_match','Publisher_newname','Publisher_abbreviation']].head(100)
# Out:
#                                             Publisher  \
# 0                                                 Cup
# 1                                                 Acs
# 2                                                 Acs
# 3                                                 Acs
# 4                                                 Acs
# 5                                                 Acs
# 6                                                 Acs
# 7                                                 Acs
# 8        Acs (Amercian Chemical Society) Publications
# 9        Acs (Amercian Chemical Society) Publications
# 10       Acs (Amercian Chemical Society) Publications
# 11       Acs (Amercian Chemical Society) Publications
# 12       Acs (Amercian Chemical Society) Publications
# 13                                   Acs Publications
# 14                                   Acs Publications
# 15                                      Aga Institute
# 16                                              Ambsb
# 17              American Association Of Immunologists
# 18              American Association Of Immunologists
# 19                          American Chemical Society
# 20                          American Chemical Society
# 21                          American Chemical Society
# 22                          American Chemical Society
# 23                          American Chemical Society
# 24                          American Chemical Society
# 25                          American Chemical Society
# 26                          American Chemical Society
# 27                          American Chemical Society
# 28                          American Chemical Society
# 29                          American Chemical Society
# ..                                                ...
# 70  American Society For Biochemistry And Molecula...
# 71  American Society For Biochemistry And Molecula...
# 72  American Society For Biochemistry And Molecula...
# 73  American Society For Biochemistry And Molecula...
# 74  American Society For Biochemistry And Molecula...
# 75  American Society For Biochemistry And Molecula...
# 76  American Society For Biochemistry And Molecula...
# 77  American Society For Biochemistry And Molecula...
# 78  American Society For Biochemistry And Molecula...
# 79  American Society For Biochemistry And Molecula...
# 80  American Society For Biochemistry And Molecula...
# 81       American Society For Investigative Pathology
# 82                  American Society For Microbiology
# 83                  American Society For Microbiology
# 84                  American Society For Microbiology
# 85                  American Society For Microbiology
# 86                  American Society For Microbiology
# 87                  American Society For Microbiology
# 88                  American Society For Microbiology
# 89                  American Society For Microbiology
# 90                  American Society For Microbiology
# 91                  American Society For Microbiology
# 92                  American Society For Microbiology
# 93                  American Society For Microbiology
# 94                  American Society For Microbiology
# 95                  American Society For Microbiology
# 96                  American Society For Microbiology
# 97                  American Society For Microbiology
# 98                 American Society For Microbiology
# 99               American Society For Microbiology \n
#
#                                       Publisher_match  \
# 0                          Cambridge University Press
# 1                           American Chemical Society
# 2                           American Chemical Society
# 3                           American Chemical Society
# 4                           American Chemical Society
# 5                           American Chemical Society
# 6                           American Chemical Society
# 7                           American Chemical Society
# 8                           American Chemical Society
# 9                           American Chemical Society
# 10                          American Chemical Society
# 11                          American Chemical Society
# 12                          American Chemical Society
# 13                          American Chemical Society
# 14                          American Chemical Society
# 15                                      Aga Institute
# 16                                              Asbmb
# 17              American Association Of Immunologists
# 18              American Association Of Immunologists
# 19                          American Chemical Society
# 20                          American Chemical Society
# 21                          American Chemical Society
# 22                          American Chemical Society
# 23                          American Chemical Society
# 24                          American Chemical Society
# 25                          American Chemical Society
# 26                          American Chemical Society
# 27                          American Chemical Society
# 28                          American Chemical Society
# 29                          American Chemical Society
# ..                                                ...
# 70  American Society For Biochemistry And Molecula...
# 71  American Society For Biochemistry And Molecula...
# 72  American Society For Biochemistry And Molecula...
# 73  American Society For Biochemistry And Molecula...
# 74  American Society For Biochemistry And Molecula...
# 75  American Society For Biochemistry And Molecula...
# 76  American Society For Biochemistry And Molecula...
# 77  American Society For Biochemistry And Molecula...
# 78  American Society For Biochemistry And Molecula...
# 79  American Society For Biochemistry And Molecula...
# 80  American Society For Biochemistry And Molecula...
# 81       American Society For Investigative Pathology
# 82                  American Society For Microbiology
# 83                  American Society For Microbiology
# 84                  American Society For Microbiology
# 85                  American Society For Microbiology
# 86                  American Society For Microbiology
# 87                  American Society For Microbiology
# 88                  American Society For Microbiology
# 89                  American Society For Microbiology
# 90                  American Society For Microbiology
# 91                  American Society For Microbiology
# 92                  American Society For Microbiology
# 93                  American Society For Microbiology
# 94                  American Society For Microbiology
# 95                  American Society For Microbiology
# 96                  American Society For Microbiology
# 97                  American Society For Microbiology
# 98                  American Society For Microbiology
# 99               American Society For Microbiology \n
#
#                                     Publisher_newname Publisher_abbreviation
# 0                          Cambridge University Press                    CUP
# 1                           American Chemical Society                    ACS
# 2                           American Chemical Society                    ACS
# 3                           American Chemical Society                    ACS
# 4                           American Chemical Society                    ACS
# 5                           American Chemical Society                    ACS
# 6                           American Chemical Society                    ACS
# 7                           American Chemical Society                    ACS
# 8                           American Chemical Society                    ACS
# 9                           American Chemical Society                    ACS
# 10                          American Chemical Society                    ACS
# 11                          American Chemical Society                    ACS
# 12                          American Chemical Society                    ACS
# 13                          American Chemical Society                    ACS
# 14                          American Chemical Society                    ACS
# 15                                      Aga Institute                    AGA
# 16                                              Ambsb                      A
# 17              American Association Of Immunologists                    AAI
# 18              American Association Of Immunologists                    AAI
# 19                          American Chemical Society                    ACS
# 20                          American Chemical Society                    ACS
# 21                          American Chemical Society                    ACS
# 22                          American Chemical Society                    ACS
# 23                          American Chemical Society                    ACS
# 24                          American Chemical Society                    ACS
# 25                          American Chemical Society                    ACS
# 26                          American Chemical Society                    ACS
# 27                          American Chemical Society                    ACS
# 28                          American Chemical Society                    ACS
# 29                          American Chemical Society                    ACS
# ..                                                ...                    ...
# 70  American Society For Biochemistry And Molecula...                  ASBMB
# 71  American Society For Biochemistry And Molecula...                  ASBMB
# 72  American Society For Biochemistry And Molecula...                  ASBMB
# 73  American Society For Biochemistry And Molecula...                  ASBMB
# 74  American Society For Biochemistry And Molecula...                  ASBMB
# 75  American Society For Biochemistry And Molecula...                  ASBMB
# 76  American Society For Biochemistry And Molecula...                  ASBMB
# 77  American Society For Biochemistry And Molecula...                  ASBMB
# 78  American Society For Biochemistry And Molecula...                  ASBMB
# 79  American Society For Biochemistry And Molecula...                  ASBMB
# 80  American Society For Biochemistry And Molecula...                  ASBMB
# 81       American Society For Investigative Pathology                   ASIP
# 82                  American Society For Microbiology                    ASM
# 83                  American Society For Microbiology                    ASM
# 84                  American Society For Microbiology                    ASM
# 85                  American Society For Microbiology                    ASM
# 86                  American Society For Microbiology                    ASM
# 87                  American Society For Microbiology                    ASM
# 88                  American Society For Microbiology                    ASM
# 89                  American Society For Microbiology                    ASM
# 90                  American Society For Microbiology                    ASM
# 91                  American Society For Microbiology                    ASM
# 92                  American Society For Microbiology                    ASM
# 93                  American Society For Microbiology                    ASM
# 94                  American Society For Microbiology                    ASM
# 95                  American Society For Microbiology                    ASM
# 96                  American Society For Microbiology                    ASM
# 97                  American Society For Microbiology                    ASM
# 98                  American Society For Microbiology                    ASM
# 99               American Society For Microbiology \n                  ASM\n
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Cleaning is done, then we can:

# %% [markdown]
# ### 1. Determine the five most common journals and the total articles for each

# %%
most_common_journal = apc['Journal_newname'].value_counts()
print(most_common_journal[0:5])
# Out:
# Plos One                           191
# Journal Of Biological Chemistry     65
# Bmc Public Health                   43
# Neuroimage                          31
# Nucleic Acids Research              29
# Name: Journal_newname, dtype: int64

# %% [markdown]
# ### 2. Calculate the mean, median, and standard deviation of the open-access cost per article for each journal.

# %%
#Cleaning cost column (removing pound signs and convert str to float)

def cleaningNumbers(dirtyNumbers):
    number = 0.00
    if dirtyNumbers != []:
        number = float(dirtyNumbers[0])
    return number

apc['cost_number'] = apc.cost.apply(lambda x:  cleaningNumbers(re.findall(r'\d*\.\d*$',x)))


#Calculate the mean, median, and standard deviation of the open-access cost per article for each journal.
results = pd.DataFrame(apc[['Journal_newname','cost_number']])

total_statistics['mean'] = results[['Journal_newname','cost_number']].groupby('Journal_newname').mean()
total_statistics['median'] = results[['Journal_newname','cost_number']].groupby('Journal_newname').median()
total_statistics['std'] = results[['Journal_newname','cost_number']].groupby('Journal_newname').std()


round(total_statistics[['mean','median','std']].head(100),2)
# Out:
#                                                        mean   median      std
# Journal_newname
# Academy Of Nutrition And Dietetics                  2379.54  2379.54      NaN
# Acs Chemical Biology                                1201.75  1227.28   511.95
# Acs Chemical Neuroscience                               NaN      NaN      NaN
# Acs Nano                                                NaN      NaN      NaN
# Acta Crystallographica Section D: Biological Cr...   772.58   772.58     1.64
# Acta Crystallographica Section F: Structural Bi...   796.64   796.64    15.61
# Acta Crystallographica, Section D                    757.18   757.18      NaN
# Acta Crystallography D                               774.19   774.19      NaN
# Acta D                                              1543.22  1543.22  1121.56
# Acta Dermato Venereologica                           653.96   653.96      NaN
# Acta F                                               754.90   754.90      NaN
# Acta Neuropathologica                               2096.06  2076.00   238.45
# Acta Opthalmologica                                 2270.16  2270.16      NaN
# Acta Physiol                                        1991.50  1991.50      NaN
# Addiction                                           2136.22  2136.22   306.48
# Advances In Experimental Medicine And Biology       1928.46  1928.46     0.01
# Age                                                 2170.14  2170.14   237.79
# Age And Ageing                                      2040.00  2040.00      NaN
# Ageing & Society                                    1695.00  1695.00      NaN
# Aging Cell                                          1970.57  1970.57      NaN
# Aids                                                2059.31  1968.63   281.07
# Aids Behav                                          1834.77  1834.77      NaN
# Aids Care                                           2294.22  2316.01   126.42
# Aids Journal                                        2015.72  2015.72      NaN
# Aids Research And Therapy                           1240.00  1240.00      NaN
# Aids Uk                                             1836.92  1836.92     0.00
# Alcohol And Alcoholism                              2040.00  2040.00      NaN
# Alimentrary Pharmacology & Therapeutics             2373.59  2373.59     0.00
# Am J Bioeth                                         1804.19  1804.19      NaN
# Americal Journal Of Psychiatry                      2350.02  2350.02      NaN
# ...                                                     ...      ...      ...
# Autophagy                                            601.10   601.10      NaN
# Azania: Archaeological Research In Africa           1823.76  1823.76      NaN
# Bba - Molecular Basis Of Disease                    2366.57  2366.57      NaN
# Behavior Research And Therapy                       2271.63  2269.53    50.39
# Behavioral Neuroscience                             3147.71  3209.63   109.11
# Behavioural Brain Research                          2298.35  2298.35      NaN
# Biinformatics                                       1047.00  1047.00      NaN
# Biochem Journal                                     1800.00  1800.00      NaN
# Biochem Soc Trans                                   1800.00  1800.00      NaN
# Biochemical And Biophysical Research Communicat...  1860.90  1860.90   545.18
# Biochemical Journal                                 1896.67  1800.00   142.01
# Biochemical Pharmacology                            2961.92  2961.92      NaN
# Biochemical Society Transactions                    1600.00  1800.00   624.50
# Biochemistry                                         665.64   665.64      NaN
# Biochimica Et Bioohysica Acta - Gene Regulatory...  2476.42  2476.42      NaN
# Biochimica Et Bioohysica Acta - Molecular Basis...  2339.10  2339.10    45.06
# Biochimica Et Biophysica Acta (Bba) - Molecular...  2415.37  2415.37      NaN
# Biochimie                                           2315.48  2315.48      NaN
# Bioconjugate Chemistry                              1565.26  1565.26      NaN
# Bioethics                                           1934.46  1935.22    40.37
# Biogerontology                                      2282.59  2282.59      NaN
# Bioinformatics                                      1885.00  1870.00   215.02
# Bioinformatics Online                               1133.33   850.00   490.75
# Biol Open                                           1014.74  1014.74      NaN
# Biological Chemistry                                 946.55   946.55      NaN
# Biological Psychiatry                               2343.04  2379.65   145.76
# Biological Psychology                               2435.38  2435.38      NaN
# Biologicial Chemistry                               1281.59  1281.59      NaN
# Biology                                             1836.91  1836.91      NaN
# Biology Letters                                     1665.00  1680.00   318.90
#
# [100 rows x 3 columns]
